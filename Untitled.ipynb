# %%
from splinter import Browser
from bs4 import BeautifulSoup
import json

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword=data+scientist&sc.keyword=data+scientist&locT=N&locId=1&jobType='
browser.visit(url)

# %%
html = browser.find_by_xpath("//script[@type='application/ld+json']")
dict_ = eval(BeautifulSoup(html.html,'html.parser').text.replace("\n",""))
#html = browser.find_by_tag('body').html
#soup = BeautifulSoup(html, 'html5lib')
#title = dict_['title']
#company = dict_['hiringOrganization']['name']
#print(dict_)
a = dict_['itemListElement'][0]['position']

t=''
if t:
    print('success')

# %%
print(soup.prettify())
pretty_html = soup.prettify()
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <div id="FlexTestFF">
#    <div class="testMQ mqHH">
#    </div>
#    <div class="testMQ mqTab">
#    </div>
#    <div class="testMQ mqDT">
#    </div>
#   </div>
#   <div id="UserAlertBarSubstitute">
#   </div>
#   <header class="" id="TopNav">
#    <div class="hidden hideMob" id="NoCookieSupportBanner">
#     <div class="flex-grid">
#      <div class="col span-1-6">
#      </div>
#      <div class="col span-2-3 center">
#       <div class="ib">
#        <p class="margVertSm">
#         Glassdoor will not work properly unless browser cookie support is enabled.
#         <a href="/about/cookies.htm">
#          Learn how to enable cookies
#         </a>
#         .
#        </p>
#       </div>
#      </div>
#      <div class="col span-1-6">
#      </div>
#     </div>
#    </div>
#    <nav>
#     <div class="container-logo">
#      <a href="/index.htm" target="_top">
# ...

# %%
print(browser.html)
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/" class="flex canvas svgfilters cssfilters no-touchevents"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# glassdoor: http://ogp.me/ns/fb/glassdoor#"><!-- because the getter clears the value --><script src="https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.SImU6QSfREo.O/m=auth2/exm=client,plusone/rt=j/sv=1/d=1/ed=1/am=wQ/rs=AGLTcCP44pMpWDXaal5DLxE6fT5610UZRw/cb=gapi.loaded_1" async=""></script><script src="https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.SImU6QSfREo.O/m=client,plusone/rt=j/sv=1/d=1/ed=1/am=wQ/rs=AGLTcCP44pMpWDXaal5DLxE6fT5610UZRw/cb=gapi.loaded_0" async=""></script><script type="text/javascript" async="" src="https://sb.scorecardresearch.com/c2/18019367/cs.js"></script><script src="https://pagead2.googlesyndication.com/pagead/osd.js"></script><script src="https://securepubads.g.d
# ...

# %%
inpt = browser.find_by_id('KeywordSearch')

# %%
inpt.type('Data Scientist', slowly=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-83ca4daa5b6f> in <module>()
# ----> 1 inpt.type('Data Scientist', slowly=True).click
#
# AttributeError: 'TypeIterator' object has no attribute 'click'

# %%
browser.find_by_id('KeywordSearch').first.visable
