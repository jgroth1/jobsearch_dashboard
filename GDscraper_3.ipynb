# %%
from splinter import Browser
from bs4 import BeautifulSoup
import datetime
import os
import json
import time
import re

# Sets the root url
root_url = 'https://www.glassdoor.com'

# Sets the search parameters
time_period = "Last Day"
keyword = 'Data Scientist'
location = 'United States'
# Set path variables

corpus_path = '/Users/grothjd/DS_bootcamp/jobsearch_dashboard/corpus3/'



# Sets the path to the chrome driver
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# directs the browser to visit the root site and sleeps for 2 seconds
browser.visit(root_url)
time.sleep(2)

# Fills out the form for job title and location and sleeps for 2 seconds
browser.find_by_xpath("//input[@id='KeywordSearch']").fill(keyword)
browser.find_by_xpath("//input[@id='LocationSearch']").fill(location)
browser.find_by_id('HeroSearchButton').click()
time.sleep(2)

# Select date posted drop down and Set date range to search
browser.find_by_text("Date Posted").click()
time.sleep(1)
browser.find_by_text(time_period).click()
time.sleep(2)

# %%
# initialize page count
n = 1

# run while there is still a next button
while True:
    try:
        x_button = browser.find_by_css('div.xBtn')
        if x_button:
            x_button.click()
    except Exception as e:
        print(e)
    test_url = browser.url
    
    
    #creates directory to save all files
    date = datetime.datetime.strftime(datetime.datetime.now(), '%d-%m-%Y')
    path = corpus_path + date + '/Page_' + str(n) + '/'
    if not os.path.exists(path):
        os.makedirs(path) 

    
    
    elements = browser.find_by_xpath("//li[@class='jl']")
    
    for element in elements:
        try:
            x_button = browser.find_by_css('div.xBtn')
            if x_button:
                x_button.click()
        except Exception as e:
            print(e)
        try:
            element.click()
            time.sleep(2)
            job_title = browser.find_by_xpath("//h1[@class='jobTitle h2 strong']")

            #print(job_title.html)


            job_title = job_title.html

            job_title = str(job_title)

            company = str(browser.find_by_xpath("//a[@class='plain strong empDetailsLink']").html)
            print(company)

            company_info = browser.find_by_xpath("//div[@class='compInfo']")

            if len(company_info.find_by_tag('span')) == 2:
                city_state = str(company_info.find_by_tag('span')[1].html)
                rating = str(company_info.find_by_tag('span')[0].html)
                rating = rating[0:3]
                print(city_state)

                print(rating)
            elif len(company_info.find_by_tag('span')) == 1:
                city_state = company_info.find_by_tag('span').html
                rating = 'NA'
                print(city_state)
                print(rating)

            job_description = str(browser.find_by_xpath("//div[@class='jobDescriptionContent desc']").html)

            date = datetime.datetime.strftime(datetime.datetime.now(), '%d-%m-%Y')

            job = {'job title': job_title, 'company': company, 'city state': city_state, 'rating': rating, 'job description': job_description}

            try:
                filename = company.replace(" ", "") + '-' + job_title.replace(" ", "").replace("/", "-") + '.json'
                with open(path + filename, 'w') as f:
                    f.write(json.dumps(job))
                    print('Saved to file : ' + filename)
            except Exception as e:
                print(e)
            time.sleep(2)
        except Exception as e:
            print(e)
    
    next_button = browser.find_by_css('li.next')
    if next_button:
        next_button.click()
        time.sleep(2)
    else:
        break
    n += 1
# Out:
# Health Catalyst
# – Salt Lake City, UT
# 4.5
# Saved to file : HealthCatalyst-DataScientist-healthcare.ai.json
# Pixar Animation Studios
# – Emeryville
# 4.3
# Saved to file : PixarAnimationStudios-ResearchScientist.json
# Hopper
# – Cambridge, MA
# 4.0
# Saved to file : Hopper-DataScientist.json
# Verizon Wireless
# – Basking Ridge, NJ
# 3.6
# Saved to file : VerizonWireless-DataScientist.json
# N.F Smith &amp; Associates
# – Houston, Texas, United States
# 4.2
# Saved to file : N.FSmith&amp;Associates-DataScientist.json
# Glassdoor
# – San Francisco, CA
# 4.0
# Saved to file : Glassdoor-DataScientist,MachineLearningIntern.json
# Stratagem Group
# – Alexandria, VA
# 4.0
# Saved to file : StratagemGroup-DataScientist.json
# re:group
# – Ann Arbor, MI
# 4.0
# Saved to file : re:group-PaidSearchandAnalyticsManager.json
# Coca-Cola Company
# – Atlanta, GA
# 3.6
# Saved to file : Coca-ColaCompany-DataScientist.json
# Ericsson-Worldwide
# – Santa Clara, California
# 3.4
# Saved to file : Ericsson-Worldwide-JuniorDataEngineer-MLandAI.json
# Ericsson-Worldwide
# – Santa Clara, California
# 3.4
# Saved to file : Ericsson-Worldwide-DataScientist-MLandAI.json
# Apple
# – Austin, Texas
# 4.0
# Saved to file : Apple-DataScientist.json
# KAISER
# – Oakland, CA
# 3.9
# Saved to file : KAISER-PredictiveAnalytics-SeniorDataScientist.json
# ADLIB
# – Bath
# 4.8
# Saved to file : ADLIB-DataScientist.json
# Everlane
# – San Francisco, CA
# 3.8
# Saved to file : Everlane-DataScientist.json
# Intent Media
# – New York, NY
# 4.7
# Saved to file : IntentMedia-DataScientist.json
# Job Juncture
# – Columbus, OH
# 5.0
# Saved to file : JobJuncture-DataScientist.json
# Vevo
# – San Francisco, CA
# 3.2
# Saved to file : Vevo-DataScientist.json
# Rakuten
# – Salt Lake City
# 2.5
# Saved to file : Rakuten-DataScientist.json
# Tencent America LLC
# – Palo Alto, CA, United States
# 4.1
# Saved to file : TencentAmericaLLC-DataScientist.json
# Change Healthcare
# – Emeryville
# 3.0
# Saved to file : ChangeHealthcare-DataScientist.json
# MarkMonitor
# – USA - San Francisco, CA
# 3.3
# Saved to file : MarkMonitor-SeniorDataScientist.json
# McClatchy
# – Raleigh, NC, United States
# 2.9
# Saved to file : McClatchy-ProductManager-Data.json
# Kforce
# – Salt Lake City, UT
# 3.7
# Saved to file : Kforce-DataScientist.json
# Ericsson-Worldwide
# – Santa Clara, California
# 3.4
# Saved to file : Ericsson-Worldwide-SeniorDataScientist(s).json
# CyberCoders
# – San Francisco, CA
# 3.9
# Saved to file : CyberCoders-DataScientist.json
# MarkMonitor
# – San Francisco, CA
# 3.3
# Saved to file : MarkMonitor-SeniorSearchSoftwareEngineer-DataScientist.json
# DATA Inc.
# – New York, New York
# 3.1
# Saved to file : DATAInc.-DataScientist.json
# Presbyterian Healthcare Services
# – Albuquerque, NM, US
# 3.6
# Saved to file : PresbyterianHealthcareServices-DATAWAREHOUSESYSTEMANALYST-SENIOR-ITENTERPRISEDATAWAREHOUSE.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# KAISER
# – Riverside, CA
# 3.9
# Saved to file : KAISER-ClinicalLabScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Investor Management Services
# – Charlotte, NC
# 4.4
# Saved to file : InvestorManagementServices-DataAnalyst.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Even
# –
# 5.0
# Saved to file : Even-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Tonal
# – San Francisco, CA, US
# 5.0
# Saved to file : Tonal-DataScientist,Analytics.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# The Money Source
# – Meriden, CT
# 4.5
# Saved to file : TheMoneySource-DefaultReportingandAnalyticsManager.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Optym
# – Gainesville
# 4.3
# Saved to file : Optym-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Crossover Health
# – San Clemente, California
# 2.5
# Saved to file : CrossoverHealth-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Northern Trust
# – Tempe, AZ
# 3.7
# Saved to file : NorthernTrust-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Micron
# – Boise, ID
# 3.7
# Saved to file : Micron-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Cyber Defense Technologies
# – Reston, VA
# NA
# Saved to file : CyberDefenseTechnologies-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# PEAK6
# – Chicago, IL
# 2.7
# Saved to file : PEAK6-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Puget Sound Energy
# – Bellevue, WA
# 3.1
# Saved to file : PugetSoundEnergy-SeniorDataScientistorDataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Aetna Inc.
# – New York, NY
# 3.3
# Saved to file : AetnaInc.-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Blucora
# – Irving, TX
# 3.4
# Saved to file : Blucora-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Seneca Resources
# – Richmond, Virginia
# 4.3
# Saved to file : SenecaResources-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# IEM
# – Arlington, VA
# 3.5
# Saved to file : IEM-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# HireNetworks
# – Raleigh, NC
# 4.5
# Saved to file : HireNetworks-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# American Chemical Society
# – Columbus, US-OH
# 3.1
# Saved to file : AmericanChemicalSociety-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Rose International
# – Creve Coeur, MO
# 4.4
# Saved to file : RoseInternational-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# The Judge Group, Inc.
# – Irving, TX
# 3.6
# Saved to file : TheJudgeGroup,Inc.-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Arby's
# – Atlanta, Georgia
# 3.4
# Saved to file : Arby's-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# CALNET
# – St. Louis, MO,US
# 3.6
# Saved to file : CALNET-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# GenapSys, Inc.
# – Redwood City, CA
# 3.3
# Saved to file : GenapSys,Inc.-SignalProcessing&amp;DataAnalyst.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Origin2Future
# – Chicago, Illinois
# NA
# Saved to file : Origin2Future-DataAnalyst-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Directly Software
# – San Francisco, CA
# 4.8
# Saved to file : DirectlySoftware-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# CMP.jobs
# – New York, NY
# 4.3
# Saved to file : CMP.jobs-DataScientist.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Geli
# – San Francisco, CA
# 2.0
# Saved to file : Geli-DataScientist,Forecasting.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# GQR Global Markets
# – Phoenix, AZ
# 3.6
# Saved to file : GQRGlobalMarkets-LeadDataScientist&amp;Engineer.json
# Message: element not visible
#   (Session info: chrome=68.0.3440.106)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.13.6 x86_64)
#
# Fanatics
# – San Mateo, CA
# 3.5
# Saved to file : Fanatics-LeadDataScientist.json
# FedEx
# – Coraopolis, PA
# 3.7
# Saved to file : FedEx-DataScientist.json
# Stripe
# – San Francisco
# 4.6
# Saved to file : Stripe-DataScientist.json
# EMC Insurance
# – Des Moines
# 3.4
# Saved to file : EMCInsurance-DataScientist.json
# The J. M. Smucker Company
# – Columbus, OH
# 3.5
# Saved to file : TheJ.M.SmuckerCompany-DataScientist.json
# BlackHorse Solutions
# – Herndon, VA
# NA
# Saved to file : BlackHorseSolutions-BlackHorseDataScientist.json
# Groupon
# – Seattle, United States
# 3.5
# Saved to file : Groupon-DataScientist.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-DataScientist.json
# Primus Software Corporation
# – Piscataway, NJ
# 3.5
# Saved to file : PrimusSoftwareCorporation-DataScientist.json
# Wyle Laboratories, Inc.
# – Houston, TX
# 2.9
# Saved to file : WyleLaboratories,Inc.-DataScientist.json
# Monsanto
# – Saint Louis, MO
# 4.0
# Saved to file : Monsanto-DataScientist.json
# Franklin Templeton Investments
# –
# 3.6
# Saved to file : FranklinTempletonInvestments-DataScientist.json
# Booz Allen Hamilton Inc.
# – Arlington, VA
# 3.7
# Saved to file : BoozAllenHamiltonInc.-DataScientist.json
# Yamaha Motor Corp
# – Cypress, CA
# 3.4
# Saved to file : YamahaMotorCorp-DataScientist.json
# Aware Software
# – Atlanta, GA
# 3.2
# Saved to file : AwareSoftware-DataScientist.json
# Spotify
# – New York, NY, United States
# 4.1
# Saved to file : Spotify-DataScientist(Product).json
# Aegon
# – Denver, CO
# 3.5
# Saved to file : Aegon-DataScientist.json
# SuddenLink Communications
# – Plano, TX
# 2.9
# Saved to file : SuddenLinkCommunications-DataScientist.json
# Diverse Lynx
# – Portland, OR
# 4.0
# Saved to file : DiverseLynx-DataScientist.json
# Intel Corp.
# – Phoenix, AZ
# 3.8
# Saved to file : IntelCorp.-DataScientist.json
# Thermo Fisher Scientific
# – CA
# 3.3
# Saved to file : ThermoFisherScientific-DataScientist.json
# YourMechanic
# – Mountain View, CA
# 3.4
# Saved to file : YourMechanic-DataScientist.json
# Lawrence Livermore National Laboratory
# – Livermore, CA
# 4.3
# Saved to file : LawrenceLivermoreNationalLaboratory-DataScientist.json
# University of Southern California
# – Marina Del Rey, CA
# 4.3
# Saved to file : UniversityofSouthernCalifornia-DataScientist.json
# Gencove, Inc.
# – Manhattan, NY
# NA
# Saved to file : Gencove,Inc.-DataScientist.json
# Code Pilot
# – Austin, TX
# NA
# Saved to file : CodePilot-DataScientist.json
# Robert Half Technology
# – Chicago, IL
# 3.1
# Saved to file : RobertHalfTechnology-DataScientist.json
# Roofstock
# – Oakland, CA
# 4.8
# Saved to file : Roofstock-SrDataScientist.json
# Collabera
# – New York, New York
# 3.9
# Saved to file : Collabera-DataScientist.json
# The Meet Group
# – Greater Philadelphia Area
# 2.6
# Saved to file : TheMeetGroup-SeniorDataEngineer.json
# Ascension Information Services
# – Franklin, TN
# 3.1
# Saved to file : AscensionInformationServices-DataScientist.json
# BDO USA
# – Grand Rapids, Michigan
# 3.4
# Saved to file : BDOUSA-DataScientistI.json
# InfiCare Technologies
# – San antonio, Texas
# 3.4
# Saved to file : InfiCareTechnologies-DataScientist.json
# Omnicell
# – Raleigh, NC
# 2.9
# Saved to file : Omnicell-DataScientist.json
# Providence Health &amp; Services
# – Renton, WA
# 3.4
# Saved to file : ProvidenceHealth&amp;Services-DataScientist.json
# Daily Harvest
# – New York, NY
# 1.0
# Saved to file : DailyHarvest-DataScientist.json
# Altice USA
# – Plano, TX
# 2.4
# Saved to file : AlticeUSA-DataScientist.json
# CGI
# – Atlanta, United States
# 3.4
# Saved to file : CGI-DataScientist.json
#
# – Lowell, Massachusetts
# NA
# Saved to file : -DataScientist.json
# Technosoft Corporation
# – Morrisville, North Carolina
# 3.5
# Saved to file : TechnosoftCorporation-DataScientist.json
# Johns Hopkins Health Care
# – Glen Burnie, MD
# 3.4
# Saved to file : JohnsHopkinsHealthCare-DataScientist.json
# dbMotion
# – Pittsburgh, PA
# 2.8
# Saved to file : dbMotion-DataScientist.json
# UC San Francisco
# – San Francisco
# 4.0
# Saved to file : UCSanFrancisco-DataScientist.json
#
# – Cincinnati, Ohio
# NA
# Saved to file : -DataScientist.json
# World Wrestling Entertainment
# – Stamford, CT
# 3.0
# Saved to file : WorldWrestlingEntertainment-SeniorDataScientist.json
# Quant AI
# – Bellevue, WA
# NA
# Saved to file : QuantAI-DataScientist.json
# Rainmaker Resources, LLC
# – Cincinnati, OH
# NA
# Saved to file : RainmakerResources,LLC-DataScientist.json
# McKinsey &amp; Company
# – Boston, United States
# 4.3
# Saved to file : McKinsey&amp;Company-SeniorDataScientist-Operations.json
# MasterClass
# – San Francisco, CA
# 4.6
# Saved to file : MasterClass-DirectorofAnalyticsandDataScience.json
# CAS
# – Columbus, Ohio, United States
# 2.8
# Saved to file : CAS-DataScientist.json
# Celgene Corporation
# – Cambridge, MA
# 3.6
# Saved to file : CelgeneCorporation-Sr.Scientist,EarlyDiscoveryBiology(Immunology).json
# TDB
# – Linthicum, US-MD
# 3.4
# Saved to file : TDB-DataScientist.json
# QuantumBlack
# – Chicago, IL
# 5.0
# Saved to file : QuantumBlack-PrincipalDataScientist.json
# Amazon
# – San Diego, CA
# 3.8
# Saved to file : Amazon-Sr.MachineLearningScientist.json
# Twitch
# – San Francisco, CA
# 3.5
# Saved to file : Twitch-SeniorAppliedScientist-Recommendations.json
# Guideline, Inc.
# – San Mateo, CA, US
# 4.8
# Saved to file : Guideline,Inc.-SeniorDataScientist.json
# Kraft Heinz Company
# – Glenview, IL
# 2.8
# Saved to file : KraftHeinzCompany-SrScientist,PackagingDevelopment-Foodservice.json
# Johnson &amp; Johnson
# – Titusville, New Jersey
# 4.0
# Saved to file : Johnson&amp;Johnson-ClinicalScientist(AssociateDirector)ExperimentalMedicineEarlyDevelopmentOncology.json
# CyberCoders
# – San Mateo, CA
# 3.9
# Saved to file : CyberCoders-SeniorDataScientist.json
# Booz Allen Hamilton Inc.
# – Saint Louis, MO
# 3.7
# Saved to file : BoozAllenHamiltonInc.-DataScientist,Junior.json
# AbbVie
# – North Chicago, USA
# 3.7
# Saved to file : AbbVie-DataScientistI.json
# Stripe
# –
# 4.6
# Saved to file : Stripe-Datascientist.json
# Centene Corporation
# – Chicago, Illinois
# 3.1
# Saved to file : CenteneCorporation-DataScientistI.json
# Moffitt Cancer Center
# – Tampa, FL
# 3.7
# Saved to file : MoffittCancerCenter-RESEARCHDATASPECIALIST.json
# Black Knight Financial Services
# – Philadelphia, Pennsylvania
# 3.3
# Saved to file : BlackKnightFinancialServices-DataScientistI.json
# The Aerospace Corporation
# – El Segundo, CA
# 3.5
# Saved to file : TheAerospaceCorporation-DataScientist.json
# Trinity Industries
# – Dallas, TX
# 3.3
# Saved to file : TrinityIndustries-DataModeler.json
# Sartorius
# – Virtual
# 3.6
# Saved to file : Sartorius-PrincipalDataScientist.json
# pymetrics
# – New York, NY
# 4.9
# Saved to file : pymetrics-DataScientist:NLPSpecialist.json
# Kforce
# – Madison, WI
# 3.7
# Saved to file : Kforce-DataScientistII.json
# MasterClass
# – San Francisco, CA
# 4.6
# Saved to file : MasterClass-DirectorofAnalyticsandDataScience.json
# Centene Corporation
# – Saint Louis, Missouri
# 3.1
# Saved to file : CenteneCorporation-LeadDataScientist.json
# Booz Allen Hamilton Inc.
# – Washington, DC
# 3.7
# Saved to file : BoozAllenHamiltonInc.-ResearchDataScientist.json
# Intuitive Surgical
# – US-CA-Sunnyvale, California
# 4.6
# Saved to file : IntuitiveSurgical-SeniorDigitalAnalyticsManager.json
# Red Ventures
# – Charlotte, NC
# 2.9
# Saved to file : RedVentures-DataArchitect.json
# CyberCoders
# – Austin, TX
# 3.9
# Saved to file : CyberCoders-DataScientist-ContracttoHire.json
# AMRI
# – US-NY-Buffalo
# 2.8
# Saved to file : AMRI-ResearchScientistI–ProteinExpression&amp;Conjugation.json
# CyberCoders
# – San Jose, CA
# 3.9
# Saved to file : CyberCoders-DirectorofDataScientist.json
# Ericsson-Worldwide
# – Santa Clara, California
# 3.4
# Saved to file : Ericsson-Worldwide-DataEngineer(s)-MLandAI.json
# Subaru of America
# – New Jersey, Cherry Hill
# 3.9
# Saved to file : SubaruofAmerica-LeadProgrammerAnalyst-DataScientist.json
# CyberCoders
# – Sunnyvale, CA
# 3.9
# Saved to file : CyberCoders-DataScientist*-ECL.json
# pymetrics
# – New York, NY
# 4.9
# Saved to file : pymetrics-DataScientist:ComputerVisionSpecialist.json
# CyberCoders
# – Sunnyvale, CA
# 3.9
# Saved to file : CyberCoders-DataScientist-ECL-Remote*.json
# Turnberry Solutions
# – Philadelphia, PENNSYLVANIA
# 4.6
# Saved to file : TurnberrySolutions-ClouderaDataEngineer.json
# ERPi
# – Washington, DC
# 4.3
# Saved to file : ERPi-SeniorDataScientist.json
# Ericsson-Worldwide
# – Santa Clara, California
# 3.4
# Saved to file : Ericsson-Worldwide-SeniorDataEngineer-MLandAI.json
# VTS3
# – New York, NY
# 5.0
# Saved to file : VTS3-SeniorDataScientist.json
# Hopper
# – Cambridge, MA
# 4.0
# Saved to file : Hopper-SeniorSoftwareEngineer-BigData.json
# Abbott Laboratories
# – North Chicago, IL
# 3.6
# Saved to file : AbbottLaboratories-QualityDataScientist.json
# Jackson Lewis
# – Sacramento, CA
# 3.4
# Saved to file : JacksonLewis-DataAnalyst.json
# Visa
# – Foster City, CA
# 3.3
# Saved to file : Visa-NewGrad(AdvancedDegree)-DataScientist-Sr.DataScientist.json
# Expedia
# – Bellevue, Washington
# 3.8
# Saved to file : Expedia-AssociateDataScientist.json
# Coursera
# – Mountain View, CA
# 3.5
# Saved to file : Coursera-StaffDataScientist.json
# Syapse
# – Radnor, PA
# 3.8
# Saved to file : Syapse-DataEngineer.json
# ClimaCell
# – Boston, MA, US
# 5.0
# Saved to file : ClimaCell-AtmosphericDataScientist-Meteorologist.json
# Microsoft
# – Redmond, Washington
# 4.1
# Saved to file : Microsoft-Data&amp;AppliedScientist.json
# Centric Consulting
# – Cincinnati
# 4.6
# Saved to file : CentricConsulting-DataAnalyst.json
# S&amp;P Global
# – Boston, MA US
# 3.5
# Saved to file : S&amp;PGlobal-QuantitativeAnalyst-DataScientist.json
# Guidance Software
# – US, NY, New York
# 3.8
# Saved to file : GuidanceSoftware-DataScientist,MagellanPresales.json
# Hire Velocity
# – Dayton, OH
# 4.0
# Saved to file : HireVelocity-DataScientist-Analyst.json
# Color Genomics
# –
# 4.9
# Saved to file : ColorGenomics-SeniorDataScientist.json
# Expedia
# – Bellevue, Washington
# 3.8
# Saved to file : Expedia-SeniorDataScientist.json
# Navstar
# – Alexandria, VA
# 4.3
# Saved to file : Navstar-DataScientist(Developer).json
# NYU Langone Health
# – New York, NY
# 3.8
# Saved to file : NYULangoneHealth-AssistantResearchScientist.json
# Mentor Graphics
# – US - OR, Wilsonville
# 4.1
# Saved to file : MentorGraphics-DataAnalyst,Finance.json
# SAP
# – Palo Alto
# 4.5
# Saved to file : SAP-DataScientist-MachineLearning.json
# SpringML
# – Pleasanton, CA
# 3.4
# Saved to file : SpringML-BigDataEngineer.json
# Citibank
# – New York
# 3.5
# Saved to file : Citibank-Developer-DataScientist-AVP.json
# CitiGroup
# – NAM-USA-New York
# 3.6
# Saved to file : CitiGroup-Developer-DataScientist-AVP.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-SeniorAppliedScientist.json
# Dataiku
# – New York, NY
# 4.9
# Saved to file : Dataiku-ExperiencedDataScientist.json
# Credibly
# – New York, United States
# 3.5
# Saved to file : Credibly-DataScientist-PortfolioManagementStrategyandAnalytics-NewYork,NY.json
# Stratagem Group
# – Aurora, CO
# 4.0
# Saved to file : StratagemGroup-MachineLearningEngineer.json
# EY
# – Secaucus, New Jersey, United States
# 3.7
# Saved to file : EY-ITAdvisor,DataandAnalytics(DataScientist)(SeniorManager)(MultiplePositions).json
# National Renewable Energy Lab
# – Golden, CO
# 3.6
# Saved to file : NationalRenewableEnergyLab-CloudDataEngineer.json
# Kforce
# – Houston, TX
# 3.7
# Saved to file : Kforce-SeniorDataScientist.json
# Elsevier
# – United States
# 3.3
# Saved to file : Elsevier-EditorinChief,DataScienceJournal.json
# Microsoft
# – Redmond, Washington
# 4.1
# Saved to file : Microsoft-SRDataScientist.json
# Northrop Grumman
# – Monterey, CA
# 3.7
# Saved to file : NorthropGrumman-DataScientist2.json
# Crowe
# – Indianapolis, IN
# 3.8
# Saved to file : Crowe-DataScientist-AppliedTechnology.json
# IBM
# – Armonk
# 3.6
# Saved to file : IBM-AccountingDataScientist.json
# Experian
# – United States
# 3.6
# Saved to file : Experian-AnalyticalConsultant–DataVisualization(Remote).json
# Nike
# – Oregon, United States
# 3.9
# Saved to file : Nike-ExpertDataScientist.json
# Facebook
# – Menlo Park, California
# 4.4
# Saved to file : Facebook-NetworkDataScientist.json
# CyberCoders
# – San Jose, CA
# 3.9
# Saved to file : CyberCoders-DecisionScientist.json
# Uber
# – San Francisco, California
# 4.2
# Saved to file : Uber-DataScientist-Research&amp;Economics.json
# GE Transportation
# – Chicago, IL
# 3.2
# Saved to file : GETransportation-SrDataScientistOperationsResearch.json
# NYU Langone Health
# – New York, NY
# 3.8
# Saved to file : NYULangoneHealth-ResearchDataAssociate(PerDiem).json
# McKinsey &amp; Company
# – New York City, United States
# 4.3
# Saved to file : McKinsey&amp;Company-DataScientist-HealthcareAnalytics&amp;Delivery,AdvancedAnalytics.json
# Parkland Health and Hospital System
# – Dallas, TX
# 3.3
# Saved to file : ParklandHealthandHospitalSystem-EnterpriseDataScientist.json
# Microsoft
# – Sunnyvale, California
# 4.1
# Saved to file : Microsoft-Sr.Data&amp;AppliedScientist.json
# SAIC
# – United States-KY-FORT KNOX
# 3.6
# Saved to file : SAIC-LegacyDataMigrationDataScientist.json
# PNC Financial Services Group
# – PA - Pittsburgh
# 3.4
# Saved to file : PNCFinancialServicesGroup-DataScientistLead.json
# Microsoft
# – Bellevue, Washington
# 4.1
# Saved to file : Microsoft-PrincipalData&amp;AppliedScientist.json
# Net2Source
# – Phoenix, AZ
# 3.2
# Saved to file : Net2Source-DataEngineer-TechnicalDataScientist.json
# Veeva Systems
# – Pleasanton, CA
# 3.5
# Saved to file : VeevaSystems-SeniorDataScientist.json
# ESRI
# – Redlands, CA
# 3.7
# Saved to file : ESRI-SeniorDataScientist.json
# Extron Electronics
# – Anaheim, CA
# 2.8
# Saved to file : ExtronElectronics-Sr.DataScientist.json
# 21st Century Fox
# – Playa Vista, CA
# 3.6
# Saved to file : 21stCenturyFox-LeadDataScientist,Marketing.json
# Case Interactive
# – Lyndhurst, New Jersey
# NA
# Saved to file : CaseInteractive-LeadDataModeler-DataScientist.json
# Bayer
# – Whippany , New Jersey
# 3.8
# Saved to file : Bayer-PrincipalDataScientist.json
# CyberCoders
# – Union City, CA
# 3.9
# Saved to file : CyberCoders-MarketingDataScientist.json
# Klaviyo
# – Boston, MA
# 4.0
# Saved to file : Klaviyo-DataScienceSoftwareEngineer.json
# The Judge Group, Inc.
# – Secaucus, NJ
# 3.6
# Saved to file : TheJudgeGroup,Inc.-Sr.DataScientistManager.json
# Kforce
# – Secaucus, NJ
# 3.7
# Saved to file : Kforce-SeniorDataScientistManager.json
# Talent Logic (Singapore)
# – Waltham, MA
# 4.0
# Saved to file : TalentLogic(Singapore)-SeniorLeadDataScientist.json
# Back Country Store
# – Park City, UT
# NA
# Saved to file : BackCountryStore-Jr.DataScientist.json
# Etsy
# – San Francisco, CA
# 3.8
# Saved to file : Etsy-DataScientist,MachineLearning&amp;AI.json
# Aetna Inc.
# – Hartford, CT
# 3.3
# Saved to file : AetnaInc.-SrDataScientist.json
# JBS USA
# – Greeley, CO
# 3.0
# Saved to file : JBSUSA-DataScientist-BusinessIntelligence.json
# Seagate Technology
# – Longmont, CO (US)
# 3.0
# Saved to file : SeagateTechnology-DataScientist-Engineer.json
# Ancestry
# – San Francisco
# 3.1
# Saved to file : Ancestry-DataScientist,Marketing.json
# Nike
# – Oregon
# 3.9
# Saved to file : Nike-ExpertDataScientist-Nike.json
# Lazard
# – New York, New York, United States
# 4.0
# Saved to file : Lazard-2019SummerInternship–DataScientist.json
# Amazon
# – Cambridge, MA
# 3.8
# Saved to file : Amazon-ResearchDataScientist.json
# WEX
# – South Portland, ME
# 3.1
# Saved to file : WEX-DataScientist2.json
# Microsoft
# – Sunnyvale, California
# 4.1
# Saved to file : Microsoft-SeniorData&amp;AppliedScientist.json
# Panasonic Avionics Corporation
# – Pleasanton, CA
# 3.2
# Saved to file : PanasonicAvionicsCorporation-PrincipalDataScientist.json
# T-Mobile
# – Bellevue, WA
# 4.0
# Saved to file : T-Mobile-SrDataScientist.json
# Amazon
# – Bellevue, WA
# 3.8
# Saved to file : Amazon-DataEngineer,AlexaSmartHome-IOT.json
# KPMG
# – Mclean, VA
# 3.8
# Saved to file : KPMG-SeniorAssociate,DataScientist.json
# 21st Century Fox
# – Playa Vista, CA
# 3.6
# Saved to file : 21stCenturyFox-LeadDataScientist,Marketing.json
# The Judge Group, Inc.
# – Creve Coeur, MO
# 3.6
# Saved to file : TheJudgeGroup,Inc.-DATASCIENTIST-SENIOR.json
# Greene Resources
# – Raleigh, NC
# 3.4
# Saved to file : GreeneResources-DataScientistandManagementConsultant.json
# Karna, LLC
# – Hyattsville, MD
# 2.9
# Saved to file : Karna,LLC-LeadDataScientist-NLP.json
# Kforce
# – Houston, TX
# 3.7
# Saved to file : Kforce-SystemsDataScientist.json
# Pinterest
# – San Francisco, CA
# 4.2
# Saved to file : Pinterest-MachineLearningEngineer,Anti-Abuse.json
# AdColony
# – Bellevue, WA, US
# 2.3
# Saved to file : AdColony-SeniorDataAnalyst-AdSystems.json
# Beacon Hill Staffing Group
# – Boston, Massachusetts
# 4.5
# Saved to file : BeaconHillStaffingGroup-LeadDataScientist.json
# Klaviyo
# – Boston, MA
# 4.0
# Saved to file : Klaviyo-SeniorDataScientist.json
# OSI Engineering
# – Santa Clara, CA
# 4.9
# Saved to file : OSIEngineering-DataScientist,MachineLearningforanAutomotiveSoftwareCompany.json
# Kforce
# – Boston, MA
# 3.7
# Saved to file : Kforce-LeadDataScientist.json
# Kforce
# – New York, NY
# 3.7
# Saved to file : Kforce-Lead-ManagerDataScientist.json
# Kforce
# – New York, NY
# 3.7
# Saved to file : Kforce-Senior-LeadDataScientist.json
# Kforce
# – Secaucus, NJ
# 3.7
# Saved to file : Kforce-SeniorDataScientistManager.json
# PwC
# – OR-Portland
# 3.8
# Saved to file : PwC-AnalyticInsights-DataScientistSrAssociate.json
# IBM
# – Washington DC&nbsp;
# 3.6
# Saved to file : IBM-Entry-LevelDataScientist.json
# Arkema
# – King Of Prussia, PA
# 3.5
# Saved to file : Arkema-Scientist.json
# Kforce
# – Greenwood Village, CO
# 3.7
# Saved to file : Kforce-Junior-Mid-LevelDataScientist.json
# Novartis
# – San Diego, CA
# 3.7
# Saved to file : Novartis-DataScientist-Novartis\-GNF.json
# Rose International
# – Tarrytown, NY
# 4.4
# Saved to file : RoseInternational-Scientist.json
# Amgen
# – Juncos, Puerto Rico
# 3.7
# Saved to file : Amgen-ProcessDevelopmentDataScientist.json
# ITA International
# – Yorktown, VA
# 3.0
# Saved to file : ITAInternational-HQDataAnalyticsCenterDataScientist.json
# DW Simpson &amp; Company
# – Wisconsin
# 4.5
# Saved to file : DWSimpson&amp;Company-DataScientist,MSorPhD.json
# 23andMe
# – South San Francisco, CA
# 4.9
# Saved to file : 23andMe-Scientist,ComputationalBiology.json
# Engility Holdings
# – Fort Bragg,North Carolina,United States
# 3.4
# Saved to file : EngilityHoldings-DataScientist-SME.json
# GroundTruth
# – Mountain View, California
# 3.2
# Saved to file : GroundTruth-ChiefDataScientist.json
# National Oilwell Varco
# – US Texas Houston
# 3.4
# Saved to file : NationalOilwellVarco-Sr.DataScientist.json
# Baker Hughes, a GE company
# – Houston, TX
# 3.5
# Saved to file : BakerHughes,aGEcompany-SrStaffDataScientist.json
# Facebook
# – Menlo Park, California
# 4.4
# Saved to file : Facebook-DataScientist,Infrastructure.json
# Freddie Mac
# – McLean, VA
# 3.7
# Saved to file : FreddieMac-DataScientistSenior.json
# Vitamin T
# – Ft. Worth, TX
# 4.8
# Saved to file : VitaminT-DataScientistandIntegrationDeveloper.json
# Nielsen
# – Chicago, IL
# 3.6
# Saved to file : Nielsen-Sr.DataScientist.json
# Health Catalyst
# – Salt Lake City, UT
# 4.5
# Saved to file : HealthCatalyst-Sr.DataScientist-LifeSciences.json
# Prospect 33
# – Jersey City, New Jersey
# 4.8
# Saved to file : Prospect33-SeniorDataScientist-AlgorithmicTrading.json
# Apixio
# – San Mateo, CA
# 4.0
# Saved to file : Apixio-Sr.DataScientist-ResearchEngineer.json
# Integrated Resources
# – - MO - Creve Coeur
# 3.2
# Saved to file : IntegratedResources-DataScientist-Senior.json
# AXIS Capital
# – Chicago, IL
# 2.5
# Saved to file : AXISCapital-SeniorDataScientist.json
# American Chemical Society
# – Columbus, US-OH
# 3.1
# Saved to file : AmericanChemicalSociety-SeniorDataScientist.json
# Ingersoll-Rand
# – Davidson, NC
# 3.6
# Saved to file : Ingersoll-Rand-SeniorDataScientist-Modeling&amp;Simulation.json
# ICONMA
# – Creve Coeur, Missouri
# 3.4
# Saved to file : ICONMA-SeniorDataScientist.json
# The Judge Group, Inc.
# – Creve Coeur, MO
# 3.6
# Saved to file : TheJudgeGroup,Inc.-SeniorResearchDataScientist(Geospatial).json
# CyberCoders
# – San Francisco, CA
# 3.9
# Saved to file : CyberCoders-DataScientist(*RelocationAssistanceAvailable).json
# Tableau Software
# – Kirkland, Washington
# 3.7
# Saved to file : TableauSoftware-SeniorSoftwareEngineer,Testing,Hyper(DataEngine).json
# Cargill, Inc.
# – Plymouth, MN
# 3.5
# Saved to file : Cargill,Inc.-Scientist.json
# Organovo
# – San Diego, CA
# 3.2
# Saved to file : Organovo-Scientist.json
# Alnylam
# – US-MA-Cambridge
# 4.1
# Saved to file : Alnylam-Scientist.json
# Lockheed Martin
# – Shelton, Connecticut
# 3.6
# Saved to file : LockheedMartin-DataAnalyst.json
# SANOFI
# – Cambridge, MA
# 3.5
# Saved to file : SANOFI-Scientist.json
# Randstad Life Sciences
# – North Chicago, IL
# NA
# Saved to file : RandstadLifeSciences-Scientist.json
# Twilio
# – San Francisco, CA
# 3.9
# Saved to file : Twilio-SoftwareEngineer-NewGrad-Voice(DataScientist).json
# Twilio
# – San Francisco, CA
# 3.9
# Saved to file : Twilio-SoftwareEngineer-NewGrad-UnderstandDataScientist.json
# Zillow
# – Seattle
# 4.2
# Saved to file : Zillow-AppliedScientist,EconomicData-Intern.json
# Allegheny Technologies (ATI)
# – Monroe, North Carolina
# 3.6
# Saved to file : AlleghenyTechnologies(ATI)-DataScientist,Engineer.json
# DMAI
# – Los Angeles, CA
# NA
# Saved to file : DMAI-DataAnalyst-Scientist.json
# Open Systems Technologies (NYC)
# – weehawken, New Jersey
# 3.1
# Saved to file : OpenSystemsTechnologies(NYC)-DataScientist115657.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-DataScientistAWSCloudCompute.json
# T. Rowe Price
# – Baltimore, MD
# 3.8
# Saved to file : T.RowePrice-QuantitativeAnalyst-PortfolioManager.json
# CyberCoders
# – San Jose, CA
# 3.9
# Saved to file : CyberCoders-DataEngineer.json
# stanleyreid
# – Springfield, VA
# NA
# Saved to file : stanleyreid-DataScientist:TS-SCI.json
# CyberCoders
# – Belmont, CA
# 3.9
# Saved to file : CyberCoders-DataAnalyst.json
# QuantumBlack
# – Chicago, IL
# 5.0
# Saved to file : QuantumBlack-SeniorDataEngineer.json
#
# – Lowell, Massachusetts
# NA
# Saved to file : -SeniorDataScientist.json
# Eurofins Scientific
# – PA, Lancaster
# 2.8
# Saved to file : EurofinsScientific-SeniorDataReviewScientist.json
# Job Juncture
# – Franklin, NE
# 5.0
# Saved to file : JobJuncture-ResearchScientist-MachineLearning.json
# Allied Global Services
# – Missouri
# 3.6
# Saved to file : AlliedGlobalServices-DataScientistIII.json
# CSL
# – Kankakee, Illinois
# 3.0
# Saved to file : CSL-Scientist,DataManagement.json
# Integrus Solutions
# – Silicon, Valley
# NA
# Saved to file : IntegrusSolutions-ModelingAnalyst-DataScientist.json
# Memorial Sloan Kettering
# – New York, NY
# 4.0
# Saved to file : MemorialSloanKettering-SeniorStrategicAnalyst-DataScientist.json
# Kforce
# – Secaucus, NJ
# 3.7
# Saved to file : Kforce-SeniorDataScientist-CustomerAnalytics.json
# SHS, Incorporated
# – Philadelphia, PA
# 5.0
# Saved to file : SHS,Incorporated-ScientistII,DMPK(Biotransformation).json
# Clinical Pathology Laboratories
# – US-TX-Austin
# 3.0
# Saved to file : ClinicalPathologyLaboratories-LaboratoryDataScientist.json
# Digital Management, Inc.
# – US-DC-
# 3.5
# Saved to file : DigitalManagement,Inc.-TSClearedSeniorDataScientist.json
# AgilOne
# – Sunnyvale, CA
# 3.8
# Saved to file : AgilOne-DataEngineerIntern.json
# Earny
# – Los Angeles, CA
# 4.2
# Saved to file : Earny-DataAnalystIntern.json
# Brammer Bio
# – Alachua, FL
# 3.1
# Saved to file : BrammerBio-Scientist–DownstreamPD.json
# University of Miami Miller School of Medicine
# – Miami, FL
# 3.3
# Saved to file : UniversityofMiamiMillerSchoolofMedicine-Scientist.json
# Promega
# – US-WI-Madison
# 4.2
# Saved to file : Promega-ResearchScientist3-4.json
# Applied Materials
# – United States-California-CA,Santa Clara
# 3.8
# Saved to file : AppliedMaterials-DataScientistIII-(B3).json
# Link Technologies (Las Vegas)
# – Las Vegas, NV
# 3.9
# Saved to file : LinkTechnologies(LasVegas)-BigDataEngineer.json
# Hired by Matrix, Inc.
# – Del Mar, California
# 4.5
# Saved to file : HiredbyMatrix,Inc.-AssociateScientist.json
# Caterpillar
# – United States-Illinois-Morton
# 3.5
# Saved to file : Caterpillar-SeniorDataScientist(SupplyChainPerformance).json
# Nike
# – New York, United States
# 3.9
# Saved to file : Nike-UserExperienceLeadMembershipDataScientist.json
# Social Sentinel
# – Burlington, VT
# NA
# Saved to file : SocialSentinel-SeniorDataScientist.json
# Highmark Health
# – Pittsburgh, PA
# 2.9
# Saved to file : HighmarkHealth-DataScientist-PharmacySharedServices.json
# Civis Analytics
# – Chicago, IL
# 4.5
# Saved to file : CivisAnalytics-SeniorAppliedDataScientist,Commercial.json
# Waste Management
# – Texas, USA
# 3.3
# Saved to file : WasteManagement-DataScientist-Pricing&amp;RevenueManagement.json
# Amgen
# – Newbury Park, CA
# 3.7
# Saved to file : Amgen-SeniorEngineerResearchDataScientist.json
# Immuta
# – College Park, MD
# NA
# Saved to file : Immuta-DataScientist-PrivacySpecialist.json
#
# – Cincinnati, Ohio
# NA
# Saved to file : -SrDataScientist.json
# J.P. Morgan
# – Palo Alto
# 3.8
# Saved to file : J.P.Morgan-DataScientistLead-DigitalProductsManager.json
# Curriculum Associates
# – Littleton, MA, United States
# 4.5
# Saved to file : CurriculumAssociates-OrderManagementDataAnalyst.json
# Highmark Health
# – Pittsburgh, PA
# 2.9
# Saved to file : HighmarkHealth-SeniorDataScientist-(R&amp;D).json
# CyberCoders
# – Cambridge, MA
# 3.9
# Saved to file : CyberCoders-AssociateDirectorNeuroscienceScientist.json
# eGenesis
# –
# 5.0
# Saved to file : eGenesis-Scientist-SeniorScientist,Immunology.json
# Fate Therapeutics, Inc.
# – San Diego, CA
# 4.6
# Saved to file : FateTherapeutics,Inc.-SeniorScientist-Scientist,.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:NLP-FSPoly.json
# Unity Technologies
# – San Francisco, CA
# 3.8
# Saved to file : UnityTechnologies-SeniorDataScientist,GamesEconomyOptimization.json
# J.P. Morgan
# – New York, NY
# 3.8
# Saved to file : J.P.Morgan-CIB-QuantitativeDataScientist-Engineer-VP.json
# HealthOne System Support
# – Denver, CO
# NA
# Saved to file : HealthOneSystemSupport-DivisionDirectorClinicalDataScientist.json
# CyberCoders
# – Cambridge, MA
# 3.9
# Saved to file : CyberCoders-AssociateScientistDiscoveryBiology.json
# Horizontal Integration
# – Eden Prairie, Minnesota
# 4.3
# Saved to file : HorizontalIntegration-LeadDataEngineer.json
# Facebook
# – Menlo Park, California
# 4.4
# Saved to file : Facebook-DataEngineer,Analytics-Intern.json
# Earny
# – Los Angeles, CA
# 4.2
# Saved to file : Earny-DataAnalystIntern.json
# Parsons Commercial Technology Group Inc.
# – Silver Spring, MD
# NA
# Saved to file : ParsonsCommercialTechnologyGroupInc.-Scientist.json
# Visa
# – Foster City, CA
# 3.3
# Saved to file : Visa-DataScientist-EngineerNewGrad(Master'sorPhD).json
# Kelly Services
# – San Diego, CA
# 3.5
# Saved to file : KellyServices-AssociateScientist.json
# State Street Global Advisors
# – Boston, MA
# 2.9
# Saved to file : StateStreetGlobalAdvisors-SSGAAIEngineer&amp;DataScientist,VP.json
# Immuta
# – College Park, MD
# NA
# Saved to file : Immuta-ResearchScientist-DataScience.json
# 23andMe
# – South San Francisco, CA
# 4.9
# Saved to file : 23andMe-Scientist,BioanalyticalAssayDevelopment.json
# ATI
# – NC, USA
# 2.9
# Saved to file : ATI-DataScientist,Engineer.json
# Eurofins Lancaster Laboratories
# – PA, Lancaster
# NA
# Saved to file : EurofinsLancasterLaboratories-SeniorDataReviewScientist.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:Counterintelligence-FSPoly.json
# Chase
# – Palo Alto
# 3.6
# Saved to file : Chase-DataScientistLead-DigitalProductsManager.json
# Citigroup Inc
# – New York, New York
# 3.6
# Saved to file : CitigroupInc-AVP-DataScientist-NewYork,NY.json
# Vanguard
# – Malvern, PA
# 3.3
# Saved to file : Vanguard-PrincipalDataScientistArtificialIntelligenceMachineLearningScientist-FinancialAdvice.json
# Allen Institute
# – Seattle, WA
# 3.1
# Saved to file : AllenInstitute-ScientistI-NeuroanatomyandDataAnalysis.json
# Bristol-Myers Squibb
# –
# 3.6
# Saved to file : Bristol-MyersSquibb-CenterforObservationalResearchandDataScience-SeniorDataScientist.json
# Allstate
# – Chicago, IL
# 3.5
# Saved to file : Allstate-Sr.DataScientist-NLP&amp;DeepLearning.json
# eGenesis
# –
# 5.0
# Saved to file : eGenesis-Scientist-SeniorScientist,Immunology.json
# LMI
# – Tysons, VA
# 3.7
# Saved to file : LMI-DataScientistactiveTS-SCIwithPolygraph.json
# Incendia Partners
# – Boston
# NA
# Saved to file : IncendiaPartners-BioinformaticsScientist.json
# Kforce
# – Costa Mesa, CA
# 3.7
# Saved to file : Kforce-LeadDataScientist-AnalyticsAnalyst.json
# Citi
# – Irving, Texas
# 3.6
# Saved to file : Citi-BI-Big-Data(Splunk-Hadoop)DataScientistandPlatformDeveloper.json
# Gilead Sciences
# – Foster City, CA (US)
# 3.2
# Saved to file : GileadSciences-ResearchScientistIHTBS.json
# CAS
# – Columbus, Ohio, United States
# 2.8
# Saved to file : CAS-SeniorDataScientist.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:Cybersecurity-FSPoly.json
# DocuSign
# – San Francisco, CA
# 4.6
# Saved to file : DocuSign-Director,ProductDataScience.json
# Citibank
# – Irving, Texas
# 3.7
# Saved to file : Citibank-BI-Big-Data(Splunk-Hadoop)DataScientistandPlatformDeveloper.json
# Software Technology Inc
# – Basking ridge, New Jersey
# 5.0
# Saved to file : SoftwareTechnologyInc-LeadDataScientist-MachineLearningProgrammer-FullTime-BaskingRidge,NJ&amp;Philadelphia,PA.json
# pymetrics
# – New York, NY
# 4.9
# Saved to file : pymetrics-Engineer,DataTeam.json
# TalentBurst
# – Cambridge, MA
# 3.5
# Saved to file : TalentBurst-ScientistI.json
# Northwell Health
# – Manhasset, NY
# 3.9
# Saved to file : NorthwellHealth-ResearchScientist.json
# Houston Methodist
# – Houston, TX
# 3.9
# Saved to file : HoustonMethodist-DataScientist-CORAdministration-HoustonMethodistResearchInstitute.json
# TalentBurst
# – Austin, TX
# 3.5
# Saved to file : TalentBurst-ScientistII.json
# Twitter
# – San Francisco, CA
# 4.0
# Saved to file : Twitter-SoftwareEngineer-DataScientist,NLP-AdsTargeting&amp;Modeling.json
# University of Miami
# – Miami, FL
# 3.9
# Saved to file : UniversityofMiami-AssistantScientist.json
# Caterpillar
# – United States-Illinois-Morton
# 3.5
# Saved to file : Caterpillar-DataScientistIII(PredictiveModelingandMachineLearningforInventoryManagementResearch).json
# GrammaTech
# – Ithaca, NY
# 4.5
# Saved to file : GrammaTech-ResearchScientist(ReverseEngineering).json
# Uptake
# – Chicago
# 3.2
# Saved to file : Uptake-DataScienceIntern-Summer.json
# Centers for Disease Control and Prevention
# – Hyattsville, MD
# 3.8
# Saved to file : CentersforDiseaseControlandPrevention-ComputerScientist.json
# Centers for Disease Control and Prevention
# – Atlanta, Georgia
# 3.8
# Saved to file : CentersforDiseaseControlandPrevention-BehavioralScientist.json
# APN Software Services Inc.
# – Newark, DE, US
# 3.9
# Saved to file : APNSoftwareServicesInc.-scientist.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:AnomalyDetection-FSPoly.json
# Parsons
# – Aberdeen, MD
# 3.4
# Saved to file : Parsons-ComputerScientist-ResearchScientist.json
# Novartis
# – Cambridge, MA
# 3.7
# Saved to file : Novartis-DataScientist,ChemicalBiology&amp;Therapeutics.json
# Galvanize
# – Denver
# 3.3
# Saved to file : Galvanize-LeadInstructor,PrincipalDataScientist.json
# Fate Therapeutics, Inc.
# – San Diego, CA
# 4.6
# Saved to file : FateTherapeutics,Inc.-Scientist,MolecularEngineering.json
# State of Virginia
# – Richmond, VA
# 3.9
# Saved to file : StateofVirginia-LeadScientist(ScientistIII).json
# University of Southern California
# – Arlington, VA
# 4.3
# Saved to file : UniversityofSouthernCalifornia-ComputerScientist.json
# Sunrise Systems, Inc.
# – San Francisco, CA
# 4.1
# Saved to file : SunriseSystems,Inc.-TranslationalScientist.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:MachineLearning-FSPoly.json
# System One
# – Hopewell, New Jersey
# 3.3
# Saved to file : SystemOne-PharmacovigilanceScientist.json
# Gilead Sciences
# – Foster City, CA (US)
# 3.2
# Saved to file : GileadSciences-SeniorResearchScientistI–DrugMetabolism.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:InsiderThreat-FSPoly.json
# eGenesis
# – Cambridge, MA, US
# 5.0
# Saved to file : eGenesis-Scientist-SeniorScientist,ModelCharacterization.json
# Leidos
# – CHANTILLY, VA
# 3.4
# Saved to file : Leidos-Sr.SystemsDataEngineerwithPolygraph.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:RiskAnalytics-FSPoly.json
# ingenium.agency
# – New York, United States
# NA
# Saved to file : ingenium.agency-LeadDataScientist.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:BehavioralAnalytics-FSPoly.json
# Nemours
# – Jacksonville, FL
# 3.5
# Saved to file : Nemours-ResearchScientist.json
# University of Wyoming
# – Laramie, WY
# 4.0
# Saved to file : UniversityofWyoming-ResearchScientist,Asst.json
# EnSafe
# – Knoxville, TN, US
# 4.0
# Saved to file : EnSafe-EnvironmentalScientist.json
# Zillow
# – Seattle
# 4.2
# Saved to file : Zillow-DataScienceIntern.json
# Paycom
# – Oklahoma City - Oklahoma City, OK
# 4.2
# Saved to file : Paycom-DataEngineer.json
# Pfizer
# – United States - New York - Pearl River
# 3.9
# Saved to file : Pfizer-SeniorScientist.json
# LSQ
# – Maitland, FL
# 4.4
# Saved to file : LSQ-RiskandDataAnalyst.json
# Kelly Services
# – Juncos, PR
# 3.5
# Saved to file : KellyServices-ProcessDevelopmentAssociateScientist|.json
# Axelon, Inc.
# – San Diego, California
# 3.5
# Saved to file : Axelon,Inc.-AssociateScientist.json
# UNC-Chapel Hill
# – Chapel Hill, NC
# 4.1
# Saved to file : UNC-ChapelHill-BioinformaticsScientist.json
# Department of the Navy
# – Fallon, Nevada
# 4.0
# Saved to file : DepartmentoftheNavy-COMPUTERSCIENTIST.json
# Can-Am Consultants, Inc.
# – Fremont, CA
# 5.0
# Saved to file : Can-AmConsultants,Inc.-ProcessScientist-ProteinPurification.json
# Alnylam Pharmaceuticals, Inc.
# – Cambridge, MA
# 4.1
# Saved to file : AlnylamPharmaceuticals,Inc.-Scientist-SeniorScientist,Neuroscience.json
# DSN
# – Springfield, IL
# 3.9
# Saved to file : DSN-ProjectManager--DataAnalytics.json
# Uchicago Argonne
# – Lemont, IL
# 4.0
# Saved to file : UchicagoArgonne-SystemsScientist.json
# Planet Pharma
# – Bridgewater, NJ
# 4.1
# Saved to file : PlanetPharma-PharmacovigilanceScientist.json
# Louisiana Department of State Civil Service
# – Baton Rouge, LA
# 5.0
# Saved to file : LouisianaDepartmentofStateCivilService-EnvironmentalHealthScientistSupervisor.json
# Equifax
# – Atlanta, GA
# 3.0
# Saved to file : Equifax-Pre-SalesAnalytics–LeadDataScientist.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:PredictiveAnalytics-FSPoly.json
# Kelly Services
# – Bethesda, MD
# 3.5
# Saved to file : KellyServices-BioinformaticsScientist-NIH.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:sole-sourcePrime-FSPoly.json
# Department of the Navy
# – Washington, DC (US)
# 4.0
# Saved to file : DepartmentoftheNavy-ENGINEER-SCIENTIST.json
# SRI International
# – Menlo Park, CA
# 3.4
# Saved to file : SRIInternational-Pharmacokinetics&amp;MetabolismScientist.json
# stanleyreid
# – Springfield, VA
# NA
# Saved to file : stanleyreid-DataScientist:TS-SCI+CIPoly.json
# INFICON
# – East Syracuse, NY
# 3.9
# Saved to file : INFICON-MassSpectrometryScientist.json
# CyberCoders
# – Albany, CA
# 3.9
# Saved to file : CyberCoders-BioinformaticsScientist.json
# Kelly Services
# – Fremont, CA
# 3.5
# Saved to file : KellyServices-ProcessScientistI-II.json
# stanleyreid
# – Fort Meade, MD
# NA
# Saved to file : stanleyreid-DataScientist:NetworkSecurity-FSPoly.json
# stanleyreid
# – Springfield, VA
# NA
# Saved to file : stanleyreid-DataScientist:TS-SCI+FSPoly.json
# Lilly UK
# – Indianapolis, Indiana
# 3.4
# Saved to file : LillyUK-ResearchScientist.json
# Pharmaceutical Product Development, LLC
# – Middleton, Wisconsin
# 3.4
# Saved to file : PharmaceuticalProductDevelopment,LLC-SeniorScientist.json
# Vanderbilt University Medical Center
# – TN-Nashville
# 3.6
# Saved to file : VanderbiltUniversityMedicalCenter-StaffScientist.json
# DuPont™ Danisco®
# – IA
# 3.0
# Saved to file : DuPont™Danisco®-ImagingScientist.json
# Synectics
# – San Diego, CA
# 3.4
# Saved to file : Synectics-AssociateScientist.json
# Johnson &amp; Johnson
# – Skillman, New Jersey
# 4.0
# Saved to file : Johnson&amp;Johnson-POSTDOCTORALSCIENTIST.json
# Monsanto Company
# – Saint Louis, Missouri
# 4.0
# Saved to file : MonsantoCompany-DataVisualizationandCommunicationsIntern.json
# Exegy
# – Saint Louis, Missouri
# 4.1
# Saved to file : Exegy-DataAnalyst.json
# University of Washington
# – Seattle, WA
# 4.1
# Saved to file : UniversityofWashington-ResearchScientist2.json
# Progressive Insurance
# – United States-Ohio-Mayfield Heights
# 3.7
# Saved to file : ProgressiveInsurance-DataAnalyst.json
# The Judge Group, Inc.
# – Columbia, OH
# 3.6
# Saved to file : TheJudgeGroup,Inc.-EnvironmentalScientist.json
# University of Texas M.D. Anderson
# – Houston, TX
# 4.1
# Saved to file : UniversityofTexasM.D.Anderson-ComputationalScientist-McCombsInstitute.json
# Boston Scientific
# – San Jose, CA
# 4.0
# Saved to file : BostonScientific-BioengineeringScientist,Prin.json
# Uber
# – San Francisco, California, United States
# 4.2
# Saved to file : Uber-DataAnalyst-DataViz.json
# US Geological Survey
# – Middleton, Wisconsin Middleton, Wisconsin
# 3.9
# Saved to file : USGeologicalSurvey-PHYSICALSCIENTIST.json
# Centers for Disease Control and Prevention
# – Atlanta, Georgia
# 3.8
# Saved to file : CentersforDiseaseControlandPrevention-HealthScientist.json
# Enervee
# – Los Angeles, CA
# 4.3
# Saved to file : Enervee-DataAnalyst|Looker.json
# Sun Chemical Corporation
# – Carlstadt, NJ
# 3.6
# Saved to file : SunChemicalCorporation-ColorScientist.json
# Alpha Consulting
# – CA - Irvine
# 4.0
# Saved to file : AlphaConsulting-Scientist-Immunology.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-AppliedScientist.json
# The Fountain Group
# – San Diego, CA
# 4.0
# Saved to file : TheFountainGroup-EntryLevelAssociateScientist.json
# C4 Therapeutics, Inc.
# – Watertown
# 5.0
# Saved to file : C4Therapeutics,Inc.-SeniorResearchScientist-AssociateDirector,.json
# TPGS
# – Springfield, VA
# 4.1
# Saved to file : TPGS-ImageryScientist.json
# Axelon, Inc.
# – Pennington, New Jersey
# 3.5
# Saved to file : Axelon,Inc.-Scientist(Pharmacovigilance).json
# Apexigen
# – San Carlos, CA
# NA
# Saved to file : Apexigen-Scientist-Sr.Scientist-DirectorTranslationalBiomarkers.json
# MRY
# – New York, New York
# 3.3
# Saved to file : MRY-BehavioralScientist.json
# HOMER
# – New York, NY
# 5.0
# Saved to file : HOMER-SeniorDataEngineer.json
# Nirmidas Biotech, Inc
# – Palo Alto, CA
# NA
# Saved to file : NirmidasBiotech,Inc-BioassayScientist.json
# Scientific Search
# – Fair Lawn, NJ
# 3.7
# Saved to file : ScientificSearch-NeurodegenerativeBehaviorScientistPhD.json
# Eurofins Lancaster Laboratories Environmental, LLC
# – Lancaster, PA
# 2.8
# Saved to file : EurofinsLancasterLaboratoriesEnvironmental,LLC-AssociateScientist.json
# Danaher
# – Sunnyvale, CA
# 3.3
# Saved to file : Danaher-AssociateScientist.json
# Aon
# – US-IL-Chicago
# 3.4
# Saved to file : Aon-SeniorScientist.json
# Sonexus Health
# – United States
# 3.9
# Saved to file : SonexusHealth-DataAnalyst.json
# DRS Technologies
# – Dallas, TX
# 3.6
# Saved to file : DRSTechnologies-ScientistII.json
# Bayside Solutions
# – San Jose, California
# 3.6
# Saved to file : BaysideSolutions-SeniorScientist.json
# Corporate Management Group
# – Denver, CO
# 1.6
# Saved to file : CorporateManagementGroup-Scientist.json
# University of Oklahoma
# – Norman, OK
# 4.1
# Saved to file : UniversityofOklahoma-SCIENTIST-RESEARCHERIII.json
# Department of Defense
# – Hurlburt Field, FL
# 3.1
# Saved to file : DepartmentofDefense-ComputerScientist.json
# Booz Allen Hamilton Inc.
# – Washington, DC
# 3.7
# Saved to file : BoozAllenHamiltonInc.-DataAnalyst.json
# GlaxoSmithKline
# – Collegeville, PA
# 3.7
# Saved to file : GlaxoSmithKline-FormulationScientist.json
# ADN Healthcare
# – Springfield, IL
# 5.0
# Saved to file : ADNHealthcare-MedicalLabScientist.json
# St. Jude Children's Research Hospital
# – Memphis, TN
# 4.7
# Saved to file : St.JudeChildren'sResearchHospital-BioinformaticsResearchScientist-GeeleherLab.json
# Pharmaceutical Product Development
# – Middleton, WI
# 3.4
# Saved to file : PharmaceuticalProductDevelopment-AssistantScientist.json
# ProClinical
# – Plainsboro, New Jersey
# 4.6
# Saved to file : ProClinical-SeniorStaffScientistII.json
# Indigo
# – Boston, MA
# 4.7
# Saved to file : Indigo-LeadScientist,PlantEnvironment.json
# ProClinical
# – Geneva
# 4.6
# Saved to file : ProClinical-SeniorBioscientist-DiagnosticsScientist.json
# Rangam Consultants
# – Abbott Park, IL 60064
# 4.1
# Saved to file : RangamConsultants-InformationScientist.json
# Rose International
# – Menlo Park, CA
# 4.4
# Saved to file : RoseInternational-DataEngineer.json
# VanderHouwen
# – Portland, Oregon
# 4.1
# Saved to file : VanderHouwen-DataEngineer.json
# EnergeiaWorks
# – Philadelphia, PA
# 5.0
# Saved to file : EnergeiaWorks-GlassScientist.json
# TalentBurst
# – South San Francisco, CA
# 3.5
# Saved to file : TalentBurst-ScientistI-Chemistry.json
# University of Southern California
# – Arlington, VA
# 4.3
# Saved to file : UniversityofSouthernCalifornia-ComputerScientist-HPC.json
# University of Southern California
# – Marina Del Rey, CA
# 4.3
# Saved to file : UniversityofSouthernCalifornia-ComputerScientist-ArtificialIntelligence.json
# Kelly Services
# – Torrance, CA
# 3.5
# Saved to file : KellyServices-SeniorR&amp;DFermentationScientist.json
# ProClinical
# – San Francisco, California
# 4.6
# Saved to file : ProClinical-PrincipleClinicalResearchScientist.json
# ProClinical
# – Foster City, California
# 4.6
# Saved to file : ProClinical-PrincipalMedicalScientist.json
# ProClinical
# – Cambridge, Massachusetts
# 4.6
# Saved to file : ProClinical-AssociateScientist-PhysicalChemistry.json
# TalentBurst
# – Mcpherson, KS
# 3.5
# Saved to file : TalentBurst-InformationScientistII.json
# Randstad Life Sciences
# – San Diego, CA
# NA
# Saved to file : RandstadLifeSciences-ResearchScientist.json
# Raytheon BBN Technologies
# – Albuquerque, New Mexico, United States
# 3.4
# Saved to file : RaytheonBBNTechnologies-ScientistI.json
# Cardiac Pacemakers
# – Indianapolis, Indiana
# 3.0
# Saved to file : CardiacPacemakers-ResearchScientist.json
# Bristol-Myers Squibb Company
# – Syracuse, New York
# 3.6
# Saved to file : Bristol-MyersSquibbCompany-ASSISTANTSCIENTIST.json
# Apple Inc.
# – Cupertino
# 4.0
# Saved to file : AppleInc.-LearningandEducationScientist.json
# General Dynamics
# – USA--AR-Little Rock
# 3.2
# Saved to file : GeneralDynamics-DataAnalyst.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-MachineLearningScientist.json
# Travelers Companies
# – Hartford, CT
# 3.8
# Saved to file : TravelersCompanies-DataAnalyst.json
# State of North Carolina
# – Raleigh, NC
# 3.4
# Saved to file : StateofNorthCarolina-SoilScientist.json
# Bristol-Myers Squibb
# –
# 3.6
# Saved to file : Bristol-MyersSquibb-AssociateScientist.json
# Apple
# – Santa Clara, California
# 4.0
# Saved to file : Apple-LocationEstimationScientist.json
# The University of Kansas
# – Lawrence, KS
# 4.0
# Saved to file : TheUniversityofKansas-DataArchitect.json
# Zillow
# – Seattle
# 4.2
# Saved to file : Zillow-AppliedScientist,Personalization-Intern.json
# Novo Nordisk
# – Seattle, WA
# 3.8
# Saved to file : NovoNordisk-ResearchScientist-Chemistry.json
# Carolinas HealthCare System
# – Charlotte, NC
# 3.3
# Saved to file : CarolinasHealthCareSystem-SrScientist.json
# TRC Companies, Inc.
# – Cleveland, OH
# 3.5
# Saved to file : TRCCompanies,Inc.-WetlandScientist.json
# Terracon
# – Las Vegas, Nevada
# 3.4
# Saved to file : Terracon-AssistantScientist.json
# Omnigon Communications
# – Los Angeles
# 3.2
# Saved to file : OmnigonCommunications-DataAnalyst.json
# Resource Management Concepts
# – Cincinnati, OH
# 4.0
# Saved to file : ResourceManagementConcepts-EnvironmentalScientist.json
# Alnylam
# – US-MA-Cambridge
# 4.1
# Saved to file : Alnylam-Scientist-Virologist.json
# Zillow
# – Seattle
# 4.2
# Saved to file : Zillow-SeniorAppliedScientist-Personalization.json
# The Broad Institute
# – Cambridge, MA
# 4.2
# Saved to file : TheBroadInstitute-ResearchScientist,Immunology.json
# Atreca
# – Redwood City, CA
# 4.7
# Saved to file : Atreca-ScientistII,InVitroPharmacology-Oncology.json
# Aptiv
# – Santa Monica, CA
# 4.0
# Saved to file : Aptiv-MachineLearningResearchScientist.json
# University of Washington
# – Seattle, WA
# 4.1
# Saved to file : UniversityofWashington-ResearchScientist-engineer-Assistant.json
# Trace Systems
# – US-FL-Tampa
# 4.0
# Saved to file : TraceSystems-Engineer(Scientist3).json
# Personalis
# – Menlo Park, CA
# 4.0
# Saved to file : Personalis-BioinformaticsScientist.json
# University of Southern California
# – Arlington, VA
# 4.3
# Saved to file : UniversityofSouthernCalifornia-ComputerScientist-Virtualization.json
# Can-Am Consultants, Inc.
# – Ridgefield, CT
# 5.0
# Saved to file : Can-AmConsultants,Inc.-Scientist-HPLCMethodDevelopment.json
# Kellogg Company
# – Battle Creek, MI
# 3.6
# Saved to file : KelloggCompany-AssociateProduct&amp;ConsumerScientist.json
# Lockheed Martin
# – Fort Worth, Texas
# 3.6
# Saved to file : LockheedMartin-ResearchScientist.json
# AECOM
# – Kenova, West Virginia
# 3.2
# Saved to file : AECOM-EnvironmentalScientist.json
# Alcon
# – Johns Creek, GA
# 3.5
# Saved to file : Alcon-AssociateScientist-Formulations.json
# Monsanto Company
# – Saint Louis, Missouri
# 4.0
# Saved to file : MonsantoCompany-AnalyticsDataEngineer.json
# Amazon
# – Seattle, WA
# 3.8
# Saved to file : Amazon-DataEngineer.json
# Spotify
# – New York, NY, United States
# 4.1
# Saved to file : Spotify-DataEngineer.json
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
# 'ElementList' object has no attribute 'html'
